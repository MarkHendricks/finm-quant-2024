# %% [markdown]
# # FINM 250 - TA Review 3 - CAPM
# ## Tobias Rodriguez del Pozo
#
# ## 1. What is the CAPM?
#
# ### 1.1 Overview
#
# It states that **in the long run**, the expected return of a stock is equal to the risk-free rate plus a risk premium that is proportional to the stock's beta. That is, all returns are explained by the market:
#
# $$
# \mathbb{E}[r_i] = \beta_i \mathbb{E}[r_m]
# $$
# Where
# $$
# \beta_i = \frac{\text{Cov}(r_i, r_m)}{\text{Var}(r_m)}
# $$
#
# Typicall, we use the S&P 500 as a proxy for the market. The risk-free rate is normally the yield of the 3-month Treasury bill (or the repo rate). The broad class of "factor models" is a generalization of the CAPM. That is, the *core* idea of a factor model is that all returns are explained by a set of factors:
#
# $$
# \mathbb{E}[r_i] = \beta_{i,1} \mathbb{E}[r_{1}] + \beta_{i,2} \mathbb{E}[r_{2}] + \dots + \beta_{i,k} \mathbb{E}[r_{k}]
# $$
#
# For those who have seen factor models in statistics classes, they are the same thing. In typical factor model notation:
#
# $$
# \boldsymbol{X} = \boldsymbol{L} \boldsymbol{F} + \boldsymbol{\epsilon}
# $$
#
# Where $\boldsymbol{X}$ is a $p \times 1$ vector of features, $\boldsymbol{L}$ is a $p \times m$ *loadings* matrix, and $\boldsymbol{F}$ is a $m \times 1$ vector of uncorrelated, unobserved factors.
#
# Most of the effort in constructing these kinds of models is in estimating the factors. Note how the response, $\boldsymbol{X}$, is *linear* in the loadings matrix. Thus, we can estimate the loadings matrix using linear regression. Importantly, being able to set up the factor model as a linear regression means that we can use all the very powerful tools that linear regression unlocks.
#
# What statistical tool might we use to "go fishing" for factors? Hint: it involves the covariance matrix and uncorrelated vectors.
#
# ### 1.2 Implications
#
# - $\alpha$, the intercept of the regression should be zero (or statistically indistinguishable from zero).
# - The $R^2$ **does not matter** because the CAPM only care about the long run, not the deviations from the long run.
# - Information ratio should be 0 (since $\alpha$ is 0).
# - Treynor Ratio for *any* assets should be the same (since any differences in mean-returns can only be explained by differences in $\beta$).
#
# ### 1.3 Trading Strategies
#
# How would you actually trade on the CAPM or a factor model? Well, consider that this is a pricing model. That is, it tells you what the *fair price* of an asset is (in terms of returns). So, if you have a lot of confidence in your factor model, you now have a theoretical price for every asset.
#
# If the market price is above your long-term theoretical price, you should short the asset. If the market price is below your long-term theoretical price, you should buy the asset.
#
# Momentum was made popular by AQR ("Applied Quantitative Research"), a hedge fund. [A Half Century of Macro Momentum](https://www.aqr.com/Insights/Research/White-Papers/A-Half-Century-of-Macro-Momentum).
#
# ### 1.4 Misc. Regression Questions
#
# These are all from interviews I've had or heard about. Again, these are not required for the class, but they are good to think about.
#
# - Give the closed form solution for linear regression and the residuals.
# - What happens to the betas, intercept, and R^2 if there is some measurement error in your X variables? What about Y?
# - How do I determine if my betas are statistically significant?
# - When would you want to use a weighted regression? What about a robust regression?
# - What is the difference between a linear regression and a logistic regression? What is the canonical link function for a logistic regression?
# - What is the closed form solution for a logistic regression? And Ridge regression?
# - What is the difference between Ridge and Lasso regression?
# - How would you determine if your regression is overfitting?

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# This is a new trick that we can use to import modules from other directories.
import sys

# We append it to "path" meaning that Python will look in this directory when we try to import modules.
# Note that ".." means go up one directory, and then we go into the "cmds" directory.
sys.path.append("../cmds")
from utils import calc_iterative_regression

# Auto reload modules.
# %load_ext autoreload
# %autoreload 2

# Plotting settings.
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False
plt.style.use("ggplot")

pd.set_option("display.float_format", lambda x: "{:.4f}".format(x))

ADJ = 12
factors = pd.read_excel(
    "../data/factor_pricing_data.xlsx",
    sheet_name="factors (excess returns)",
    index_col=0,
    parse_dates=[0],
)

spy = factors[["MKT"]]

assets = pd.read_excel(
    "../data/factor_pricing_data.xlsx",
    sheet_name="portfolios (excess returns)",
    index_col=0,
    parse_dates=[0],
)

# %%
# Plot, Guns portfolio vs market with a linear regression line.
fig, ax = plt.subplots(figsize=(8, 5))
ax.scatter(spy, assets["Guns "], alpha=0.6)
ax.set_xlabel("Market")
ax.set_ylabel("Guns Portfolio")
ax.set_title("Guns Portfolio vs Market")

# Calculate the linear regression.
X = sm.add_constant(spy)
model = sm.OLS(assets["Guns "], X)
results = model.fit()
beta = results.params["MKT"]
alpha = results.params["const"]
r2 = results.rsquared
x = np.linspace(spy.min(), spy.max(), 100)
ax.plot(x, alpha + beta * x, color="#348ABD", label=f"R2: {r2:.2f}\nAlpha: {alpha:.4f}\nBeta: {beta:.2f}", lw=3)
ax.legend()
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

assets["MKT"] = spy

betas = []
means = []

spy_const = sm.add_constant(spy)
for asset in assets.columns:
    regr = sm.OLS(assets[asset], spy_const).fit()
    ax.scatter(regr.params[1], assets[asset].mean() * ADJ, label=asset, zorder=2)
    ax.annotate(asset, (regr.params[1], assets[asset].mean() * ADJ), zorder=3)
    betas.append(regr.params[1])
    means.append(assets[asset].mean() * ADJ)

ax.plot([0, 1.4], [0, spy.mean()[0] * ADJ * 1.4], c="black", zorder=1, alpha=0.5)
beta_mean_regr = sm.OLS(means, sm.add_constant(betas)).fit()

ax.plot(
    np.arange(0, 1.6, 0.1),
    beta_mean_regr.params[0] + beta_mean_regr.params[1] * np.arange(0, 1.6, 0.1),
    zorder=1,
    alpha=0.7,
)

ax.set_yticks(np.arange(0, 0.15, 0.02))
ax.set_xticks(np.arange(0, 1.6, 0.2))
ax.set_title("Mean Return vs. Beta")
ax.set_xlabel("Beta")
ax.set_ylabel("Mean Return")
fig.tight_layout()

# %% [markdown]
# ## 2. Replication
#
# (See TA solutions for the code).

# %% [markdown]
# ## 3. Python

# %% [markdown]
# ### Jupyter Notebook Tidbit #1: How to use the "magic" commands
#
# Jupyter is actually a wrapper around the IPython kernel. IPython is a Python interpreter that has a bunch of extra features. One of these features is the "magic" commands. These are commands that start with a `%` or `%%` and are not part of the Python language. They are specific to IPython.
#
# So actually, code cells are just blocks of text that start with `%%python`, and a markdown cell is just a block of text that starts with `%%markdown`.

# %%
# Some examples. Let's look at the documentation for the `calc_iterative_regression` function.
# %pdoc calc_iterative_regression

# Or time some code.
# %timeit calc_iterative_regression(assets, spy, one_to_many=True)

# Or list all variables of type `DataFrame` in the current namespace.
# %whos DataFrame

# Or run a specific file
# %run ../cmds/utils.py

# Or load it!
#  %load ../cmds/utils.py

# %% [markdown]
# ### Python Tidbit #1 (from last week)

# %%
rets = pd.read_excel(
    "../data/multi_asset_etf_data.xlsx",
    sheet_name="excess returns",
    index_col=0,
    parse_dates=[0],
)

# Here is another example of dictionary unpacking and where it can be useful.
# Recall from the calc_iter_regr(y, X, intercept=True, one_to_many=False, adj=12) function,
# that we have 3 different parameters that we can set. Suppose that for *this* notebook in
# particular, we want to change all of them. However, we don't want to have to repeatedly call
# the function with different parameters, eg:

calc_iterative_regression(
    rets[["IEF", "HYG", "PSP"]],
    rets[["SPY"]],
    intercept=False,
    one_to_many=True,
    adj=52,
)

# We can simply make a dictionary of the parameters we want to change, and then unpack it into
# the function.

PARAMS = {"intercept": False, "one_to_many": True, "adj": 52}

calc_iterative_regression(rets[["IEF", "HYG", "PSP"]], rets[["SPY"]], **PARAMS)

# We can also use something like functools.partial to *partially* apply the function with the
# parameters we want to change. This is useful if we want to change multiple parameters, perhaps
# in a more complex way, or by personal preference. This pre-applies the parameters we want to change,
# and returns a new function that we can call with the remaining parameters.

from functools import partial

calc_iter_regr_partial = partial(
    calc_iterative_regression, intercept=False, one_to_many=True, adj=12
)

calc_iter_regr_partial(rets[["IEF", "HYG", "PSP"]], rets[["SPY"]])

# Finally, note how we're constantly repeating rets[["IEF", "HYG", "PSP"]] and rets["SPY"] in the
# function calls! We could fix this with another partial function, but we can also use list unpacking.
VAR_LIST = [rets[["IEF", "HYG", "PSP"]], rets[["SPY"]]]

# This is what Python means when you see a function that looks like: func(*args, **kwargs)
# Note how we can end the line with a ';' to suppress the output of the function call.
calc_iterative_regression(*VAR_LIST, **PARAMS);

# %% [markdown]
# ### Python Tidbit #2: What governs being able to do operations on two different datetypes?
#
# This is based on a question I got last week, which I thought warranted a more in-depth discussion.

# %%
# Why can we do this?
as_np = np.arange(10)
as_pd = pd.Series(as_np)
# display(as_np + 10)
# display(as_pd + 10)
# display(as_np + as_pd)

# But not this?
my_list = list(range(10))
# my_list + 10

# And not this?
as_pd_reindex = as_pd.reindex(range(10, 20))
# as_pd + as_pd_reindex

# Or this?
as_np_short = np.arange(5)
# as_np + as_np_short

# Or this?
# as_pd + "A"

# It's weird, right? Why can we sometimes add a scaler to a series, an array, but not
# to a list?

# A surface level explanation is that the "+" operator is defined for list concatenation,
# but not for addition. But why?

# %%
# We introduce another special method, __add__(), which is called when we use the "+" operator.
# It allows us to *define* what happens when we use the "+" operator on our own classes, and what
# it means to add two instances of our class together - or to add our class to another class.

# Suppose I am fed up of not being able to add a scaler to a list, and I want to define my own
# class that allows me to do this. I can do this by defining my own class, and defining the __add__()
# method to work for my class.

# Why might this be a bad idea? Hint: Line 513 of this file: https://github.com/python/cpython/blob/main/Objects/listobject.c
# What language is this file in? What does this mean for performance of TobiasList?


class TobiasList(list):
    # Iterator and dictionary unpacking!
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

    def __add__(self, other):
        # Check if this is a scaler.
        if isinstance(other, int) or isinstance(other, float):
            return [i + other for i in self]
        else:
            # Otherwise, just use the default list addition.
            return super().__add__(other)

    def __mul__(self, other) -> list:
        # Check if this is a scaler.
        if isinstance(other, int) or isinstance(other, float):
            return [i * other for i in self]
        else:
            # Otherwise, just use the default list addition.
            return super().__mul__(other)

    def __pow__(self, other) -> list:
        if isinstance(other, int) or isinstance(other, float):
            return [i**other for i in self]
        else:
            return super().__pow__(other)


# TobiasList(range(10)) + 10
# TobiasList(range(10)) * 10
# TobiasList(range(10)) ** 2

# %% [markdown]
# ### Pandas Tidbit: Everything in Pandas is an Index Operation
#
# *All* Pandas operations are index operations. That is, they are operations on the index of the DataFrame. This is why Pandas is so fast. It is also why Pandas is so confusing and hard to debug. If you understand indexing, you understand Pandas.
#
# From TA Review 1: https://www.youtube.com/watch?v=pjq3QOxl9Ok

# %%
df_1 = pd.DataFrame(np.random.randn(10, 10))
df_2 = pd.DataFrame(np.random.randn(10, 10))

# This works!
# display(df_1 + df_2)

# This also works!
df_1[10] = df_2[0]
# display(df_1)

# Why? Because the indices of df_1 and df_2 are the same, so pandas knows how to add them together,
# set one to the other, etc. Now let's change the indices and see what happens.
df_2.index = range(2, 12)

# We can only add where the indices match,
# otherwise we get NaNs.
# display(df_1 + df_2)

# The same thing goes for setting
df_1[10] = df_2[0]
# display(df_1)

# So how do we actually fix this problem? There are a few ways.
df_1 = pd.DataFrame(np.random.randn(10, 10))
df_2 = pd.DataFrame(np.random.randn(10, 10))
df_2.index = range(2, 12)

# First, we reindex df_2 to match df_1.
df_2.index = df_1.index
# display(df_1 + df_2)

# Second, we can use the .add() method, which allows us to specify how we want to handle
# missing values. This will fill in missing values with 0.
# display(df_1.add(df_2, fill_value=0))

# Third, we can reset the index of both dataframes, such that their indices are the same (0,...,9).
df_2 = df_2.reset_index(drop=True)
df_1 = df_1.reset_index(drop=True)
# display(df_1 + df_2)

# Finally, we can use the .align() method, which will align the indices of both dataframes,
# and fill in missing values with NaNs.
df_1, df_2 = df_1.align(df_2, axis=0)
# display(df_1 + df_2)

# %%
# Index alignment also helps us answer questions, such as why these two cells run at different speeds.

# For-loop creation of dataframes with string indices.
my_dfs_idx = []
my_dfs = []

letters = "abcdefghijlmnopqrstuvwxyz"

for i in range(10000):
    my_dfs_idx.append(
        pd.DataFrame(
            np.random.randn(25, 10), index=[letters[j] + str(i) for j in range(25)]
        )
    )
    my_dfs.append(pd.DataFrame(np.random.randn(25, 10)))

# %%
# Concat with no index dropping.
# %timeit res = pd.concat(my_dfs, axis=0)
# Out:
# 95.3 ms ± 4.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Concat with index dropping.
# %timeit res = pd.concat(my_dfs, axis=0, ignore_index=True)
# Out:
# 88.4 ms ± 2.47 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### Python Tidbit #3: How to make your DataFrames look nice
#
# Many times, you will want to display your DataFrames in a better way. The default display, although functional, does not allow for easy reading, or highlighting of important information. In particular, you may want to:
# - Highlight the maximum and minimum values in each column.
# - Make a heatmap w/ the range of values in each column.
# - Highlight the values that are above or below a certain threshold.
# - Change the color of the foreground/background for a presentation.
# - Add a caption to the DataFrame.
# - Have some kind of "highlight" function, where you can mouse over a value and it will highlight the row and column of that value.
#
# See: https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html

# %%
# To address the above, we use the "Style" API in pandas, which allows us to apply styles to
# DataFrames. This is useful for highlighting certain values, or for applying conditional
# formatting to our data. It also enables us to create more complex visualizations of our data
# and use functions to apply styles to our data.

# Lets start with the basics: displaying all columns and rows of a DataFrame.
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# And make it wider
from IPython.core.display import HTML
HTML("<style>.container { width:100% !important; }</style>")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Now, let's create a DataFrame with some random data.
df = pd.DataFrame(np.random.randn(10, 10), columns=list("ABCDEFGHIJ"))

# Want: Highlight the maximum and minimum value in each column.
def highlight_maxmin(s):
    is_max = s == s.max()
    is_min = s == s.min()
    # Highlight the maximum value in green, and the minimum value in red.
    return ["background-color: green" if v else "background-color: red" if w else "" for v, w in zip(is_max, is_min)]
    
df.style.apply(highlight_maxmin)
# Out:
# <style type="text/css">
# #T_54d16_row1_col0, #T_54d16_row1_col8, #T_54d16_row4_col3, #T_54d16_row4_col6, #T_54d16_row5_col7, #T_54d16_row7_col2, #T_54d16_row7_col4, #T_54d16_row8_col1, #T_54d16_row9_col5, #T_54d16_row9_col9 {
#   background-color: red;
# }
# #T_54d16_row2_col1, #T_54d16_row2_col4, #T_54d16_row3_col0, #T_54d16_row3_col2, #T_54d16_row4_col5, #T_54d16_row4_col9, #T_54d16_row6_col3, #T_54d16_row7_col7, #T_54d16_row7_col8, #T_54d16_row8_col6 {
#   background-color: green;
# }
# </style>
# <table id="T_54d16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54d16_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_54d16_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_54d16_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_54d16_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_54d16_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_54d16_level0_col5" class="col_heading level0 col5" >F</th>
#       <th id="T_54d16_level0_col6" class="col_heading level0 col6" >G</th>
#       <th id="T_54d16_level0_col7" class="col_heading level0 col7" >H</th>
#       <th id="T_54d16_level0_col8" class="col_heading level0 col8" >I</th>
#       <th id="T_54d16_level0_col9" class="col_heading level0 col9" >J</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54d16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54d16_row0_col0" class="data row0 col0" >-0.352630</td>
#       <td id="T_54d16_row0_col1" class="data row0 col1" >0.588178</td>
#       <td id="T_54d16_row0_col2" class="data row0 col2" >-0.946264</td>
#       <td id="T_54d16_row0_col3" class="data row0 col3" >0.117595</td>
#       <td id="T_54d16_row0_col4" class="data row0 col4" >-0.205391</td>
#       <td id="T_54d16_row0_col5" class="data row0 col5" >0.154912</td>
#       <td id="T_54d16_row0_col6" class="data row0 col6" >0.979180</td>
#       <td id="T_54d16_row0_col7" class="data row0 col7" >0.042818</td>
#       <td id="T_54d16_row0_col8" class="data row0 col8" >0.437134</td>
#       <td id="T_54d16_row0_col9" class="data row0 col9" >0.950824</td>
#     </tr>
#     <tr>
#       <th id="T_54d16_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54d16_row1_col0" class="data row1 col0" >-2.722316</td>
#       <td id="T_54d16_row1_col1" class="data row1 col1" >-0.422230</td>
#       <td id="T_54d16_row1_col2" class="data row1 col2" >-1.354664</td>
#       <td id="T_54d16_row1_col3" class="data row1 col3" >-0.426361</td>
#       <td id="T_54d16_row1_col4" class="data row1 col4" >0.137443</td>
#       <td id="T_54d16_row1_col5" class="data row1 col5" >-1.190936</td>
#       <td id="T_54d16_row1_col6" class="data row1 col6" >2.095152</td>
#       <td id="T_54d16_row1_col7" class="data row1 col7" >0.035427</td>
#       <td id="T_54d16_row1_col8" class="data row1 col8" >-1.218970</td>
#       <td id="T_54d16_row1_col9" class="data row1 col9" >-0.192619</td>
#     </tr>
#     <tr>
#       <th id="T_54d16_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54d16_row2_col0" class="data row2 col0" >0.072898</td>
#       <td id="T_54d16_row2_col1" class="data row2 col1" >1.831336</td>
#       <td id="T_54d16_row2_col2" class="data row2 col2" >0.216543</td>
#       <td id="T_54d16_row2_col3" class="data row2 col3" >0.377062</td>
#       <td id="T_54d16_row2_col4" class="data row2 col4" >1.538938</td>
#       <td id="T_54d16_row2_col5" class="data row2 col5" >-0.777861</td>
#       <td id="T_54d16_row2_col6" class="data row2 col6" >-0.464815</td>
#       <td id="T_54d16_row2_col7" class="data row2 col7" >-1.132540</td>
#       <td id="T_54d16_row2_col8" class="data row2 col8" >0.591886</td>
#       <td id="T_54d16_row2_col9" class="data row2 col9" >-0.550189</td>
#     </tr>
#     <tr>
#       <th id="T_54d16_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54d16_row3_col0" class="data row3 col0" >0.639677</td>
#       <td id="T_54d16_row3_col1" class="data row3 col1" >-0.035791</td>
#       <td id="T_54d16_row3_col2" class="data row3 col2" >0.940667</td>
#       <td id="T_54d16_row3_col3" class="data row3 col3" >0.925390</td>
#       <td id="T_54d16_row3_col4" class="data row3 col4" >1.508967</td>
#       <td id="T_54d16_row3_col5" class="data row3 col5" >-0.103882</td>
#       <td id="T_54d16_row3_col6" class="data row3 col6" >0.016348</td>
#       <td id="T_54d16_row3_col7" class="data row3 col7" >-0.248955</td>
#       <td id="T_54d16_row3_col8" class="data row3 col8" >-0.235388</td>
#       <td id="T_54d16_row3_col9" class="data row3 col9" >-0.001831</td>
#     </tr>
#     <tr>
#       <th id="T_54d16_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_54d16_row4_col0" class="data row4 col0" >0.448203</td>
#       <td id="T_54d16_row4_col1" class="data row4 col1" >0.559089</td>
#       <td id="T_54d16_row4_col2" class="data row4 col2" >-0.019602</td>
#       <td id="T_54d16_row4_col3" class="data row4 col3" >-0.908920</td>
#       <td id="T_54d16_row4_col4" class="data row4 col4" >0.534587</td>
#       <td id="T_54d16_row4_col5" class="data row4 col5" >0.520313</td>
#       <td id="T_54d16_row4_col6" class="data row4 col6" >-2.298285</td>
#       <td id="T_54d16_row4_col7" class="data row4 col7" >-0.310445</td>
#       <td id="T_54d16_row4_col8" class="data row4 col8" >-0.094255</td>
#       <td id="T_54d16_row4_col9" class="data row4 col9" >1.244451</td>
#     </tr>
#     <tr>
#       <th id="T_54d16_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_54d16_row5_col0" class="data row5 col0" >0.204727</td>
#       <td id="T_54d16_row5_col1" class="data row5 col1" >-0.404974</td>
#       <td id="T_54d16_row5_col2" class="data row5 col2" >0.354717</td>
#       <td id="T_54d16_row5_col3" class="data row5 col3" >-0.411371</td>
#       <td id="T_54d16_row5_col4" class="data row5 col4" >0.360403</td>
#       <td id="T_54d16_row5_col5" class="data row5 col5" >-1.455011</td>
#       <td id="T_54d16_row5_col6" class="data row5 col6" >-0.515594</td>
#       <td id="T_54d16_row5_col7" class="data row5 col7" >-2.274937</td>
#       <td id="T_54d16_row5_col8" class="data row5 col8" >1.033533</td>
#       <td id="T_54d16_row5_col9" class="data row5 col9" >-0.398605</td>
#     </tr>
#     <tr>
#       <th id="T_54d16_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_54d16_row6_col0" class="data row6 col0" >0.158459</td>
#       <td id="T_54d16_row6_col1" class="data row6 col1" >-0.416276</td>
#       <td id="T_54d16_row6_col2" class="data row6 col2" >0.182185</td>
#       <td id="T_54d16_row6_col3" class="data row6 col3" >1.439213</td>
#       <td id="T_54d16_row6_col4" class="data row6 col4" >-1.310628</td>
#       <td id="T_54d16_row6_col5" class="data row6 col5" >-0.064085</td>
#       <td id="T_54d16_row6_col6" class="data row6 col6" >1.747455</td>
#       <td id="T_54d16_row6_col7" class="data row6 col7" >-0.331711</td>
#       <td id="T_54d16_row6_col8" class="data row6 col8" >0.403112</td>
#       <td id="T_54d16_row6_col9" class="data row6 col9" >0.314427</td>
#     </tr>
#     <tr>
#       <th id="T_54d16_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_54d16_row7_col0" class="data row7 col0" >-1.344747</td>
#       <td id="T_54d16_row7_col1" class="data row7 col1" >-0.715023</td>
#       <td id="T_54d16_row7_col2" class="data row7 col2" >-1.460284</td>
#       <td id="T_54d16_row7_col3" class="data row7 col3" >0.763359</td>
#       <td id="T_54d16_row7_col4" class="data row7 col4" >-2.158897</td>
#       <td id="T_54d16_row7_col5" class="data row7 col5" >0.153584</td>
#       <td id="T_54d16_row7_col6" class="data row7 col6" >-0.582982</td>
#       <td id="T_54d16_row7_col7" class="data row7 col7" >1.547001</td>
#       <td id="T_54d16_row7_col8" class="data row7 col8" >1.110813</td>
#       <td id="T_54d16_row7_col9" class="data row7 col9" >0.844966</td>
#     </tr>
#     <tr>
#       <th id="T_54d16_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_54d16_row8_col0" class="data row8 col0" >-1.261965</td>
#       <td id="T_5

# %%
# What about highlighting all values less than 0.5?
def highlight_less_than_05(s):
    return ["background-color: red" if v < -0.5 else "" for v in s]

df.style.apply(highlight_less_than_05)
# Out:
# <style type="text/css">
# #T_91115_row0_col2, #T_91115_row1_col0, #T_91115_row1_col2, #T_91115_row1_col5, #T_91115_row1_col8, #T_91115_row2_col5, #T_91115_row2_col7, #T_91115_row2_col9, #T_91115_row4_col3, #T_91115_row4_col6, #T_91115_row5_col5, #T_91115_row5_col6, #T_91115_row5_col7, #T_91115_row6_col4, #T_91115_row7_col0, #T_91115_row7_col1, #T_91115_row7_col2, #T_91115_row7_col4, #T_91115_row7_col6, #T_91115_row8_col0, #T_91115_row8_col1, #T_91115_row9_col0, #T_91115_row9_col2, #T_91115_row9_col5, #T_91115_row9_col7, #T_91115_row9_col8, #T_91115_row9_col9 {
#   background-color: red;
# }
# </style>
# <table id="T_91115">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91115_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_91115_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_91115_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_91115_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_91115_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_91115_level0_col5" class="col_heading level0 col5" >F</th>
#       <th id="T_91115_level0_col6" class="col_heading level0 col6" >G</th>
#       <th id="T_91115_level0_col7" class="col_heading level0 col7" >H</th>
#       <th id="T_91115_level0_col8" class="col_heading level0 col8" >I</th>
#       <th id="T_91115_level0_col9" class="col_heading level0 col9" >J</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91115_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91115_row0_col0" class="data row0 col0" >-0.352630</td>
#       <td id="T_91115_row0_col1" class="data row0 col1" >0.588178</td>
#       <td id="T_91115_row0_col2" class="data row0 col2" >-0.946264</td>
#       <td id="T_91115_row0_col3" class="data row0 col3" >0.117595</td>
#       <td id="T_91115_row0_col4" class="data row0 col4" >-0.205391</td>
#       <td id="T_91115_row0_col5" class="data row0 col5" >0.154912</td>
#       <td id="T_91115_row0_col6" class="data row0 col6" >0.979180</td>
#       <td id="T_91115_row0_col7" class="data row0 col7" >0.042818</td>
#       <td id="T_91115_row0_col8" class="data row0 col8" >0.437134</td>
#       <td id="T_91115_row0_col9" class="data row0 col9" >0.950824</td>
#     </tr>
#     <tr>
#       <th id="T_91115_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_91115_row1_col0" class="data row1 col0" >-2.722316</td>
#       <td id="T_91115_row1_col1" class="data row1 col1" >-0.422230</td>
#       <td id="T_91115_row1_col2" class="data row1 col2" >-1.354664</td>
#       <td id="T_91115_row1_col3" class="data row1 col3" >-0.426361</td>
#       <td id="T_91115_row1_col4" class="data row1 col4" >0.137443</td>
#       <td id="T_91115_row1_col5" class="data row1 col5" >-1.190936</td>
#       <td id="T_91115_row1_col6" class="data row1 col6" >2.095152</td>
#       <td id="T_91115_row1_col7" class="data row1 col7" >0.035427</td>
#       <td id="T_91115_row1_col8" class="data row1 col8" >-1.218970</td>
#       <td id="T_91115_row1_col9" class="data row1 col9" >-0.192619</td>
#     </tr>
#     <tr>
#       <th id="T_91115_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_91115_row2_col0" class="data row2 col0" >0.072898</td>
#       <td id="T_91115_row2_col1" class="data row2 col1" >1.831336</td>
#       <td id="T_91115_row2_col2" class="data row2 col2" >0.216543</td>
#       <td id="T_91115_row2_col3" class="data row2 col3" >0.377062</td>
#       <td id="T_91115_row2_col4" class="data row2 col4" >1.538938</td>
#       <td id="T_91115_row2_col5" class="data row2 col5" >-0.777861</td>
#       <td id="T_91115_row2_col6" class="data row2 col6" >-0.464815</td>
#       <td id="T_91115_row2_col7" class="data row2 col7" >-1.132540</td>
#       <td id="T_91115_row2_col8" class="data row2 col8" >0.591886</td>
#       <td id="T_91115_row2_col9" class="data row2 col9" >-0.550189</td>
#     </tr>
#     <tr>
#       <th id="T_91115_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_91115_row3_col0" class="data row3 col0" >0.639677</td>
#       <td id="T_91115_row3_col1" class="data row3 col1" >-0.035791</td>
#       <td id="T_91115_row3_col2" class="data row3 col2" >0.940667</td>
#       <td id="T_91115_row3_col3" class="data row3 col3" >0.925390</td>
#       <td id="T_91115_row3_col4" class="data row3 col4" >1.508967</td>
#       <td id="T_91115_row3_col5" class="data row3 col5" >-0.103882</td>
#       <td id="T_91115_row3_col6" class="data row3 col6" >0.016348</td>
#       <td id="T_91115_row3_col7" class="data row3 col7" >-0.248955</td>
#       <td id="T_91115_row3_col8" class="data row3 col8" >-0.235388</td>
#       <td id="T_91115_row3_col9" class="data row3 col9" >-0.001831</td>
#     </tr>
#     <tr>
#       <th id="T_91115_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_91115_row4_col0" class="data row4 col0" >0.448203</td>
#       <td id="T_91115_row4_col1" class="data row4 col1" >0.559089</td>
#       <td id="T_91115_row4_col2" class="data row4 col2" >-0.019602</td>
#       <td id="T_91115_row4_col3" class="data row4 col3" >-0.908920</td>
#       <td id="T_91115_row4_col4" class="data row4 col4" >0.534587</td>
#       <td id="T_91115_row4_col5" class="data row4 col5" >0.520313</td>
#       <td id="T_91115_row4_col6" class="data row4 col6" >-2.298285</td>
#       <td id="T_91115_row4_col7" class="data row4 col7" >-0.310445</td>
#       <td id="T_91115_row4_col8" class="data row4 col8" >-0.094255</td>
#       <td id="T_91115_row4_col9" class="data row4 col9" >1.244451</td>
#     </tr>
#     <tr>
#       <th id="T_91115_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_91115_row5_col0" class="data row5 col0" >0.204727</td>
#       <td id="T_91115_row5_col1" class="data row5 col1" >-0.404974</td>
#       <td id="T_91115_row5_col2" class="data row5 col2" >0.354717</td>
#       <td id="T_91115_row5_col3" class="data row5 col3" >-0.411371</td>
#       <td id="T_91115_row5_col4" class="data row5 col4" >0.360403</td>
#       <td id="T_91115_row5_col5" class="data row5 col5" >-1.455011</td>
#       <td id="T_91115_row5_col6" class="data row5 col6" >-0.515594</td>
#       <td id="T_91115_row5_col7" class="data row5 col7" >-2.274937</td>
#       <td id="T_91115_row5_col8" class="data row5 col8" >1.033533</td>
#       <td id="T_91115_row5_col9" class="data row5 col9" >-0.398605</td>
#     </tr>
#     <tr>
#       <th id="T_91115_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_91115_row6_col0" class="data row6 col0" >0.158459</td>
#       <td id="T_91115_row6_col1" class="data row6 col1" >-0.416276</td>
#       <td id="T_91115_row6_col2" class="data row6 col2" >0.182185</td>
#       <td id="T_91115_row6_col3" class="data row6 col3" >1.439213</td>
#       <td id="T_91115_row6_col4" class="data row6 col4" >-1.310628</td>
#       <td id="T_91115_row6_col5" class="data row6 col5" >-0.064085</td>
#       <td id="T_91115_row6_col6" class="data row6 col6" >1.747455</td>
#       <td id="T_91115_row6_col7" class="data row6 col7" >-0.331711</td>
#       <td id="T_91115_row6_col8" class="data row6 col8" >0.403112</td>
#       <td id="T_91115_row6_col9" class="data row6 col9" >0.314427</td>
#     </tr>
#     <tr>
#       <th id="T_91115_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_91115_row7_col0" class="data row7 col0" >-1.344747</td>
#       <td id="T_91115_row7_col1" class="data row7 col1" >-0.715023</td>
#       <td id="T_91115_row7_col2" class="data row7 col2" >-1.460284</td>
#       <td id="T_91115_row7_col3" class="data row7 col3" >0.763359</td>
#       <td id="T_91115_row7_col4" class="data row7 col4" >-2.158897</td>
#       <td id="T_91115_row7_col5" class="data row7 col5" >0.153584</td>
#       <td id="T_91115_row7_col6" class="data row7 col6" >-0.582982</td>
#       <td id="T_91115_row7_col7" class="data row7 col7" >1.547001</td>
#       <td id="T_91115_row7_col8" class="data row7 col8" >1.110813</td>
#       <td id="T_91115_row7_col9" class="data row7 col9" >0.844966</td>
#     </tr>
#     <tr>
#       <th id="T_91115_level0_row8" class="row_heading

# %%
# And a heatmap per-column?
def heatmap(s):
    return ["background-color: rgba(0, 255, 0, {})".format(v/2) for v in s]

df.style.apply(heatmap)
# Out:
# <style type="text/css">
# #T_9c233_row0_col0 {
#   background-color: rgba(0, 255, 0, -0.17631496761464976);
# }
# #T_9c233_row0_col1 {
#   background-color: rgba(0, 255, 0, 0.2940889598508523);
# }
# #T_9c233_row0_col2 {
#   background-color: rgba(0, 255, 0, -0.47313211736873395);
# }
# #T_9c233_row0_col3 {
#   background-color: rgba(0, 255, 0, 0.05879773201176395);
# }
# #T_9c233_row0_col4 {
#   background-color: rgba(0, 255, 0, -0.10269558901754967);
# }
# #T_9c233_row0_col5 {
#   background-color: rgba(0, 255, 0, 0.07745614801470006);
# }
# #T_9c233_row0_col6 {
#   background-color: rgba(0, 255, 0, 0.4895900702208126);
# }
# #T_9c233_row0_col7 {
#   background-color: rgba(0, 255, 0, 0.021409143244548175);
# }
# #T_9c233_row0_col8 {
#   background-color: rgba(0, 255, 0, 0.21856688049658404);
# }
# #T_9c233_row0_col9 {
#   background-color: rgba(0, 255, 0, 0.4754121275987416);
# }
# #T_9c233_row1_col0 {
#   background-color: rgba(0, 255, 0, -1.3611579394633788);
# }
# #T_9c233_row1_col1 {
#   background-color: rgba(0, 255, 0, -0.21111508299556966);
# }
# #T_9c233_row1_col2 {
#   background-color: rgba(0, 255, 0, -0.6773320046937701);
# }
# #T_9c233_row1_col3 {
#   background-color: rgba(0, 255, 0, -0.21318047044042895);
# }
# #T_9c233_row1_col4 {
#   background-color: rgba(0, 255, 0, 0.06872156077001362);
# }
# #T_9c233_row1_col5 {
#   background-color: rgba(0, 255, 0, -0.5954679508245324);
# }
# #T_9c233_row1_col6 {
#   background-color: rgba(0, 255, 0, 1.047576019713519);
# }
# #T_9c233_row1_col7 {
#   background-color: rgba(0, 255, 0, 0.01771366453622625);
# }
# #T_9c233_row1_col8 {
#   background-color: rgba(0, 255, 0, -0.6094847896023589);
# }
# #T_9c233_row1_col9 {
#   background-color: rgba(0, 255, 0, -0.09630945357857379);
# }
# #T_9c233_row2_col0 {
#   background-color: rgba(0, 255, 0, 0.03644917250786901);
# }
# #T_9c233_row2_col1 {
#   background-color: rgba(0, 255, 0, 0.9156681422861332);
# }
# #T_9c233_row2_col2 {
#   background-color: rgba(0, 255, 0, 0.10827134954661079);
# }
# #T_9c233_row2_col3 {
#   background-color: rgba(0, 255, 0, 0.18853089636146544);
# }
# #T_9c233_row2_col4 {
#   background-color: rgba(0, 255, 0, 0.7694688853348097);
# }
# #T_9c233_row2_col5 {
#   background-color: rgba(0, 255, 0, -0.3889303107473943);
# }
# #T_9c233_row2_col6 {
#   background-color: rgba(0, 255, 0, -0.23240742139013448);
# }
# #T_9c233_row2_col7 {
#   background-color: rgba(0, 255, 0, -0.5662698125378551);
# }
# #T_9c233_row2_col8 {
#   background-color: rgba(0, 255, 0, 0.29594296021259775);
# }
# #T_9c233_row2_col9 {
#   background-color: rgba(0, 255, 0, -0.27509469422392624);
# }
# #T_9c233_row3_col0 {
#   background-color: rgba(0, 255, 0, 0.3198383284771106);
# }
# #T_9c233_row3_col1 {
#   background-color: rgba(0, 255, 0, -0.017895735080050844);
# }
# #T_9c233_row3_col2 {
#   background-color: rgba(0, 255, 0, 0.4703334961496053);
# }
# #T_9c233_row3_col3 {
#   background-color: rgba(0, 255, 0, 0.4626950978999906);
# }
# #T_9c233_row3_col4 {
#   background-color: rgba(0, 255, 0, 0.7544834518237986);
# }
# #T_9c233_row3_col5 {
#   background-color: rgba(0, 255, 0, -0.0519407745910816);
# }
# #T_9c233_row3_col6 {
#   background-color: rgba(0, 255, 0, 0.00817419890296704);
# }
# #T_9c233_row3_col7 {
#   background-color: rgba(0, 255, 0, -0.12447737017398877);
# }
# #T_9c233_row3_col8 {
#   background-color: rgba(0, 255, 0, -0.11769392530032496);
# }
# #T_9c233_row3_col9 {
#   background-color: rgba(0, 255, 0, -0.0009154539193607416);
# }
# #T_9c233_row4_col0 {
#   background-color: rgba(0, 255, 0, 0.22410139629253395);
# }
# #T_9c233_row4_col1 {
#   background-color: rgba(0, 255, 0, 0.27954446339640204);
# }
# #T_9c233_row4_col2 {
#   background-color: rgba(0, 255, 0, -0.009800759537388933);
# }
# #T_9c233_row4_col3 {
#   background-color: rgba(0, 255, 0, -0.4544600178700342);
# }
# #T_9c233_row4_col4 {
#   background-color: rgba(0, 255, 0, 0.26729331890766883);
# }
# #T_9c233_row4_col5 {
#   background-color: rgba(0, 255, 0, 0.2601565428168641);
# }
# #T_9c233_row4_col6 {
#   background-color: rgba(0, 255, 0, -1.1491423173608404);
# }
# #T_9c233_row4_col7 {
#   background-color: rgba(0, 255, 0, -0.15522232430297075);
# }
# #T_9c233_row4_col8 {
#   background-color: rgba(0, 255, 0, -0.04712757734131589);
# }
# #T_9c233_row4_col9 {
#   background-color: rgba(0, 255, 0, 0.6222255094142116);
# }
# #T_9c233_row5_col0 {
#   background-color: rgba(0, 255, 0, 0.10236364065529623);
# }
# #T_9c233_row5_col1 {
#   background-color: rgba(0, 255, 0, -0.20248697719170394);
# }
# #T_9c233_row5_col2 {
#   background-color: rgba(0, 255, 0, 0.1773584338497561);
# }
# #T_9c233_row5_col3 {
#   background-color: rgba(0, 255, 0, -0.2056852903974935);
# }
# #T_9c233_row5_col4 {
#   background-color: rgba(0, 255, 0, 0.18020158852614931);
# }
# #T_9c233_row5_col5 {
#   background-color: rgba(0, 255, 0, -0.7275054709492506);
# }
# #T_9c233_row5_col6 {
#   background-color: rgba(0, 255, 0, -0.2577968539882439);
# }
# #T_9c233_row5_col7 {
#   background-color: rgba(0, 255, 0, -1.137468358786206);
# }
# #T_9c233_row5_col8 {
#   background-color: rgba(0, 255, 0, 0.5167665379397235);
# }
# #T_9c233_row5_col9 {
#   background-color: rgba(0, 255, 0, -0.19930240574099012);
# }
# #T_9c233_row6_col0 {
#   background-color: rgba(0, 255, 0, 0.07922940144749648);
# }
# #T_9c233_row6_col1 {
#   background-color: rgba(0, 255, 0, -0.2081380698603927);
# }
# #T_9c233_row6_col2 {
#   background-color: rgba(0, 255, 0, 0.09109248714414689);
# }
# #T_9c233_row6_col3 {
#   background-color: rgba(0, 255, 0, 0.7196064409127336);
# }
# #T_9c233_row6_col4 {
#   background-color: rgba(0, 255, 0, -0.6553140997144755);
# }
# #T_9c233_row6_col5 {
#   background-color: rgba(0, 255, 0, -0.03204257123204991);
# }
# #T_9c233_row6_col6 {
#   background-color: rgba(0, 255, 0, 0.8737277013163199);
# }
# #T_9c233_row6_col7 {
#   background-color: rgba(0, 255, 0, -0.16585566121316858);
# }
# #T_9c233_row6_col8 {
#   background-color: rgba(0, 255, 0, 0.20155579994508133);
# }
# #T_9c233_row6_col9 {
#   background-color: rgba(0, 255, 0, 0.15721356811006965);
# }
# #T_9c233_row7_col0 {
#   background-color: rgba(0, 255, 0, -0.6723734841530142);
# }
# #T_9c233_row7_col1 {
#   background-color: rgba(0, 255, 0, -0.35751133565716636);
# }
# #T_9c233_row7_col2 {
#   background-color: rgba(0, 255, 0, -0.7301418429560004);
# }
# #T_9c233_row7_col3 {
#   background-color: rgba(0, 255, 0, 0.3816793259508489);
# }
# #T_9c233_row7_col4 {
#   background-color: rgba(0, 255, 0, -1.0794483737735296);
# }
# #T_9c233_row7_col5 {
#   background-color: rgba(0, 255, 0, 0.07679195542549723);
# }
# #T_9c233_row7_col6 {
#   background-color: rgba(0, 255, 0, -0.29149098674956203);
# }
# #T_9c233_row7_col7 {
#   background-color: rgba(0, 255, 0, 0.7735007183217771);
# }
# #T_9c233_row7_col8 {
#   background-color: rgba(0, 255, 0, 0.55540673607014);
# }
# #T_9c233_row7_col9 {
#   background-color: rgba(0, 255, 0, 0.42248287232258624);
# }
# #T_9c233_row8_col0 {
#   background-color: rgba(0, 255, 0, -0.6309825317706115);
# }
# #T_9c233_row8_col1 {
#   background-color: rgba(0, 255, 0, -1.1004377519881376);
# }
# #T_9c233_row8_col2 {
#   background-color: rgba(0, 255, 0, -0.017528914956109056);
# }
# #T_9c233_row8_col3 {
#   background-color: rgba(0, 255, 0, 0.1254936745117687);
# }
# #T_9c233_row8_col4 {
#   background-color: rgba(0, 255, 0, 0.4273149448298798);
# }
# #T_9c233_row8_col5 {
#   background-color: rgba(0, 255, 0, -0.05591717277084941);
# }
# #T_9c233_row8_col6 {
#   background-color: rgba(0, 255, 0, 1.0572986643254674);
# }
# #T_9c233_row8_col7 {
#   background-color: rgba(0, 255, 0, 0.12722777858156242);
# }
# #T_9c233_row8_col8 {
#   background-color: rgba(0, 255, 0, 0.1353511627768237);
# }
# #T_9c233_row8_col9 {
#   background-color: rgba(0, 255, 0, -0.028179201234029776);
# }
# #T_9c233_row9_col0 {
#   background-color: rgba(0, 255, 0, -0.8682917879568424);
# }
# #T_9c233_row9_col1 {
#   background-color: rgba(0, 255, 0, 0.011251778396745182);
# }
# #T_9c233_row9_col2 {
#   background-color: rgba(0, 255, 0, -0.525021731779209);
# }
# #T_9c233_row9_col3 {
#   background-color: rgba(0, 255, 0, -0.13151516199888127);
# }
# #T_9c233_row9_col4 {
#   background-color: rgba(0, 255, 0, -0.03534430673477402);
# }
# #T_9c233_row9_col5 {
#   background-color: rgba(0, 255, 0, -0.9601088493301861);
# }
# #T_9c233_row9_col6 {
#   background-color: rgba(0, 255, 0, 0.15588021671752658);
# }
# #T_9c233_row9_col7 {
#   background-color: rgba(0, 255, 0, -0.5992307940610111);
# }
# #T_9c233_row9_col8 {
#   backgroun

# %%
# What about interactivity?
hover_rule = {
    "selector": "td:hover",
    "props": [("background-color", "#ffffb3"), ("color", "black")]

}

df.style.apply(heatmap).set_caption("This is an example DataFrame\n").set_table_styles([hover_rule])
# Out:
# <style type="text/css">
# #T_e261f td:hover {
#   background-color: #ffffb3;
#   color: black;
# }
# #T_e261f_row0_col0 {
#   background-color: rgba(0, 255, 0, -0.17631496761464976);
# }
# #T_e261f_row0_col1 {
#   background-color: rgba(0, 255, 0, 0.2940889598508523);
# }
# #T_e261f_row0_col2 {
#   background-color: rgba(0, 255, 0, -0.47313211736873395);
# }
# #T_e261f_row0_col3 {
#   background-color: rgba(0, 255, 0, 0.05879773201176395);
# }
# #T_e261f_row0_col4 {
#   background-color: rgba(0, 255, 0, -0.10269558901754967);
# }
# #T_e261f_row0_col5 {
#   background-color: rgba(0, 255, 0, 0.07745614801470006);
# }
# #T_e261f_row0_col6 {
#   background-color: rgba(0, 255, 0, 0.4895900702208126);
# }
# #T_e261f_row0_col7 {
#   background-color: rgba(0, 255, 0, 0.021409143244548175);
# }
# #T_e261f_row0_col8 {
#   background-color: rgba(0, 255, 0, 0.21856688049658404);
# }
# #T_e261f_row0_col9 {
#   background-color: rgba(0, 255, 0, 0.4754121275987416);
# }
# #T_e261f_row1_col0 {
#   background-color: rgba(0, 255, 0, -1.3611579394633788);
# }
# #T_e261f_row1_col1 {
#   background-color: rgba(0, 255, 0, -0.21111508299556966);
# }
# #T_e261f_row1_col2 {
#   background-color: rgba(0, 255, 0, -0.6773320046937701);
# }
# #T_e261f_row1_col3 {
#   background-color: rgba(0, 255, 0, -0.21318047044042895);
# }
# #T_e261f_row1_col4 {
#   background-color: rgba(0, 255, 0, 0.06872156077001362);
# }
# #T_e261f_row1_col5 {
#   background-color: rgba(0, 255, 0, -0.5954679508245324);
# }
# #T_e261f_row1_col6 {
#   background-color: rgba(0, 255, 0, 1.047576019713519);
# }
# #T_e261f_row1_col7 {
#   background-color: rgba(0, 255, 0, 0.01771366453622625);
# }
# #T_e261f_row1_col8 {
#   background-color: rgba(0, 255, 0, -0.6094847896023589);
# }
# #T_e261f_row1_col9 {
#   background-color: rgba(0, 255, 0, -0.09630945357857379);
# }
# #T_e261f_row2_col0 {
#   background-color: rgba(0, 255, 0, 0.03644917250786901);
# }
# #T_e261f_row2_col1 {
#   background-color: rgba(0, 255, 0, 0.9156681422861332);
# }
# #T_e261f_row2_col2 {
#   background-color: rgba(0, 255, 0, 0.10827134954661079);
# }
# #T_e261f_row2_col3 {
#   background-color: rgba(0, 255, 0, 0.18853089636146544);
# }
# #T_e261f_row2_col4 {
#   background-color: rgba(0, 255, 0, 0.7694688853348097);
# }
# #T_e261f_row2_col5 {
#   background-color: rgba(0, 255, 0, -0.3889303107473943);
# }
# #T_e261f_row2_col6 {
#   background-color: rgba(0, 255, 0, -0.23240742139013448);
# }
# #T_e261f_row2_col7 {
#   background-color: rgba(0, 255, 0, -0.5662698125378551);
# }
# #T_e261f_row2_col8 {
#   background-color: rgba(0, 255, 0, 0.29594296021259775);
# }
# #T_e261f_row2_col9 {
#   background-color: rgba(0, 255, 0, -0.27509469422392624);
# }
# #T_e261f_row3_col0 {
#   background-color: rgba(0, 255, 0, 0.3198383284771106);
# }
# #T_e261f_row3_col1 {
#   background-color: rgba(0, 255, 0, -0.017895735080050844);
# }
# #T_e261f_row3_col2 {
#   background-color: rgba(0, 255, 0, 0.4703334961496053);
# }
# #T_e261f_row3_col3 {
#   background-color: rgba(0, 255, 0, 0.4626950978999906);
# }
# #T_e261f_row3_col4 {
#   background-color: rgba(0, 255, 0, 0.7544834518237986);
# }
# #T_e261f_row3_col5 {
#   background-color: rgba(0, 255, 0, -0.0519407745910816);
# }
# #T_e261f_row3_col6 {
#   background-color: rgba(0, 255, 0, 0.00817419890296704);
# }
# #T_e261f_row3_col7 {
#   background-color: rgba(0, 255, 0, -0.12447737017398877);
# }
# #T_e261f_row3_col8 {
#   background-color: rgba(0, 255, 0, -0.11769392530032496);
# }
# #T_e261f_row3_col9 {
#   background-color: rgba(0, 255, 0, -0.0009154539193607416);
# }
# #T_e261f_row4_col0 {
#   background-color: rgba(0, 255, 0, 0.22410139629253395);
# }
# #T_e261f_row4_col1 {
#   background-color: rgba(0, 255, 0, 0.27954446339640204);
# }
# #T_e261f_row4_col2 {
#   background-color: rgba(0, 255, 0, -0.009800759537388933);
# }
# #T_e261f_row4_col3 {
#   background-color: rgba(0, 255, 0, -0.4544600178700342);
# }
# #T_e261f_row4_col4 {
#   background-color: rgba(0, 255, 0, 0.26729331890766883);
# }
# #T_e261f_row4_col5 {
#   background-color: rgba(0, 255, 0, 0.2601565428168641);
# }
# #T_e261f_row4_col6 {
#   background-color: rgba(0, 255, 0, -1.1491423173608404);
# }
# #T_e261f_row4_col7 {
#   background-color: rgba(0, 255, 0, -0.15522232430297075);
# }
# #T_e261f_row4_col8 {
#   background-color: rgba(0, 255, 0, -0.04712757734131589);
# }
# #T_e261f_row4_col9 {
#   background-color: rgba(0, 255, 0, 0.6222255094142116);
# }
# #T_e261f_row5_col0 {
#   background-color: rgba(0, 255, 0, 0.10236364065529623);
# }
# #T_e261f_row5_col1 {
#   background-color: rgba(0, 255, 0, -0.20248697719170394);
# }
# #T_e261f_row5_col2 {
#   background-color: rgba(0, 255, 0, 0.1773584338497561);
# }
# #T_e261f_row5_col3 {
#   background-color: rgba(0, 255, 0, -0.2056852903974935);
# }
# #T_e261f_row5_col4 {
#   background-color: rgba(0, 255, 0, 0.18020158852614931);
# }
# #T_e261f_row5_col5 {
#   background-color: rgba(0, 255, 0, -0.7275054709492506);
# }
# #T_e261f_row5_col6 {
#   background-color: rgba(0, 255, 0, -0.2577968539882439);
# }
# #T_e261f_row5_col7 {
#   background-color: rgba(0, 255, 0, -1.137468358786206);
# }
# #T_e261f_row5_col8 {
#   background-color: rgba(0, 255, 0, 0.5167665379397235);
# }
# #T_e261f_row5_col9 {
#   background-color: rgba(0, 255, 0, -0.19930240574099012);
# }
# #T_e261f_row6_col0 {
#   background-color: rgba(0, 255, 0, 0.07922940144749648);
# }
# #T_e261f_row6_col1 {
#   background-color: rgba(0, 255, 0, -0.2081380698603927);
# }
# #T_e261f_row6_col2 {
#   background-color: rgba(0, 255, 0, 0.09109248714414689);
# }
# #T_e261f_row6_col3 {
#   background-color: rgba(0, 255, 0, 0.7196064409127336);
# }
# #T_e261f_row6_col4 {
#   background-color: rgba(0, 255, 0, -0.6553140997144755);
# }
# #T_e261f_row6_col5 {
#   background-color: rgba(0, 255, 0, -0.03204257123204991);
# }
# #T_e261f_row6_col6 {
#   background-color: rgba(0, 255, 0, 0.8737277013163199);
# }
# #T_e261f_row6_col7 {
#   background-color: rgba(0, 255, 0, -0.16585566121316858);
# }
# #T_e261f_row6_col8 {
#   background-color: rgba(0, 255, 0, 0.20155579994508133);
# }
# #T_e261f_row6_col9 {
#   background-color: rgba(0, 255, 0, 0.15721356811006965);
# }
# #T_e261f_row7_col0 {
#   background-color: rgba(0, 255, 0, -0.6723734841530142);
# }
# #T_e261f_row7_col1 {
#   background-color: rgba(0, 255, 0, -0.35751133565716636);
# }
# #T_e261f_row7_col2 {
#   background-color: rgba(0, 255, 0, -0.7301418429560004);
# }
# #T_e261f_row7_col3 {
#   background-color: rgba(0, 255, 0, 0.3816793259508489);
# }
# #T_e261f_row7_col4 {
#   background-color: rgba(0, 255, 0, -1.0794483737735296);
# }
# #T_e261f_row7_col5 {
#   background-color: rgba(0, 255, 0, 0.07679195542549723);
# }
# #T_e261f_row7_col6 {
#   background-color: rgba(0, 255, 0, -0.29149098674956203);
# }
# #T_e261f_row7_col7 {
#   background-color: rgba(0, 255, 0, 0.7735007183217771);
# }
# #T_e261f_row7_col8 {
#   background-color: rgba(0, 255, 0, 0.55540673607014);
# }
# #T_e261f_row7_col9 {
#   background-color: rgba(0, 255, 0, 0.42248287232258624);
# }
# #T_e261f_row8_col0 {
#   background-color: rgba(0, 255, 0, -0.6309825317706115);
# }
# #T_e261f_row8_col1 {
#   background-color: rgba(0, 255, 0, -1.1004377519881376);
# }
# #T_e261f_row8_col2 {
#   background-color: rgba(0, 255, 0, -0.017528914956109056);
# }
# #T_e261f_row8_col3 {
#   background-color: rgba(0, 255, 0, 0.1254936745117687);
# }
# #T_e261f_row8_col4 {
#   background-color: rgba(0, 255, 0, 0.4273149448298798);
# }
# #T_e261f_row8_col5 {
#   background-color: rgba(0, 255, 0, -0.05591717277084941);
# }
# #T_e261f_row8_col6 {
#   background-color: rgba(0, 255, 0, 1.0572986643254674);
# }
# #T_e261f_row8_col7 {
#   background-color: rgba(0, 255, 0, 0.12722777858156242);
# }
# #T_e261f_row8_col8 {
#   background-color: rgba(0, 255, 0, 0.1353511627768237);
# }
# #T_e261f_row8_col9 {
#   background-color: rgba(0, 255, 0, -0.028179201234029776);
# }
# #T_e261f_row9_col0 {
#   background-color: rgba(0, 255, 0, -0.8682917879568424);
# }
# #T_e261f_row9_col1 {
#   background-color: rgba(0, 255, 0, 0.011251778396745182);
# }
# #T_e261f_row9_col2 {
#   background-color: rgba(0, 255, 0, -0.525021731779209);
# }
# #T_e261f_row9_col3 {
#   background-color: rgba(0, 255, 0, -0.13151516199888127);
# }
# #T_e261f_row9_col4 {
#   background-color: rgba(0, 255, 0, -0.03534430673477402);
# }
# #T_e261f_row9_col5 {
#   background-color: rgba(0, 255, 0, -0.9601088493301861);
# }
# #T_e261f_row9_col6 {
#   background-color: rgba(0, 255, 0, 0.15588021671752658);
# }
# #T_e261f_row9_col7 {
#   background-color: rgba(

# %%
# Combine everything together -- suppose we have a corporate color scheme, and 
# we want to apply it to our DataFrame.
corp_colors = {
    "blue": "#BCF4F5",
    "bluegreen": "#B4EBCA",
    "green1": "#D9F2B4",
    "green2": "#D3FAC7",
    "pink": "#FFB7C3",
    "red": "#AD2831"
}

def hex_to_rgb(hex_color):
    hex_color = hex_color.lstrip('#')
    return tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))

def apply_heatmap(s, color):
    rgb = hex_to_rgb(color)
    norm = (s - s.min()) / (s.max() - s.min())
    return [f'background-color: rgba({rgb[0]}, {rgb[1]}, {rgb[2]}, {val:.2f})' for val in norm]

def style_df(df):
    def background_color(val, color):
        return f'background-color: {color}'

    def text_color(val, color):
        return f'color: {color}'
    
    styled_df = df.style \
        .applymap(background_color, color=corp_colors['bluegreen']) \
        .apply(apply_heatmap, color=corp_colors['red'], subset=pd.IndexSlice[:, 'A']) \
        .apply(apply_heatmap, color=corp_colors['blue'], subset=pd.IndexSlice[:, 'B']) \
        .applymap(text_color, subset=pd.IndexSlice[:, df.columns[2:]], color='black') \
        .set_table_styles([{'selector': 'th.row_heading', 'props': [('background-color', corp_colors['green1'])]}]) \
        .set_table_styles([{'selector': 'th.col_heading', 'props': [('background-color', corp_colors['green2'])]}])    
    return styled_df

# Define formatting functions
def format_percentage(x):
    return "{:.2%}".format(x)

def format_currency(x):
    return "${:,.2f}".format(x)

def format_millions(x):
    return "${:,.2f}m".format(abs(x)) if x >= 0 else "$({:,.2f})m".format(abs(x))


hover_rule = {
    "selector": "td:hover",
    "props": [("background-color", "#FFB7C3"), ("color", "black")]

}

# Apply the styling function
styled_df = style_df(df)
styled_df = styled_df.set_table_styles([hover_rule]).format("{:.2f}").set_caption("This is an example DataFrame\n")

# Display columnn "C" as a % and column "D" as a currency, and column "E" as $ mm, with ( ) for negative values.
styled_df = styled_df.format({
    "A": "{:.2f}", "B": "{:.2f}",
    "C": format_percentage, "D": format_currency, "E": format_millions,
    "F": "{:.0f}", "G": "{:.0f}", "H": "{:.0f}", "I": "{:.0f}", "J": "{:.0f}"
})

# Save as an HTML file.
# styled_df.to_html("styled_df.html")

styled_df
# Out:
# <style type="text/css">
# #T_abf42 td:hover {
#   background-color: #FFB7C3;
#   color: black;
# }
# #T_abf42_row0_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.70);
# }
# #T_abf42_row0_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 0.69);
# }
# #T_abf42_row0_col2, #T_abf42_row0_col3, #T_abf42_row0_col4, #T_abf42_row0_col5, #T_abf42_row0_col6, #T_abf42_row0_col7, #T_abf42_row0_col8, #T_abf42_row0_col9, #T_abf42_row1_col2, #T_abf42_row1_col3, #T_abf42_row1_col4, #T_abf42_row1_col5, #T_abf42_row1_col6, #T_abf42_row1_col7, #T_abf42_row1_col8, #T_abf42_row1_col9, #T_abf42_row2_col2, #T_abf42_row2_col3, #T_abf42_row2_col4, #T_abf42_row2_col5, #T_abf42_row2_col6, #T_abf42_row2_col7, #T_abf42_row2_col8, #T_abf42_row2_col9, #T_abf42_row3_col2, #T_abf42_row3_col3, #T_abf42_row3_col4, #T_abf42_row3_col5, #T_abf42_row3_col6, #T_abf42_row3_col7, #T_abf42_row3_col8, #T_abf42_row3_col9, #T_abf42_row4_col2, #T_abf42_row4_col3, #T_abf42_row4_col4, #T_abf42_row4_col5, #T_abf42_row4_col6, #T_abf42_row4_col7, #T_abf42_row4_col8, #T_abf42_row4_col9, #T_abf42_row5_col2, #T_abf42_row5_col3, #T_abf42_row5_col4, #T_abf42_row5_col5, #T_abf42_row5_col6, #T_abf42_row5_col7, #T_abf42_row5_col8, #T_abf42_row5_col9, #T_abf42_row6_col2, #T_abf42_row6_col3, #T_abf42_row6_col4, #T_abf42_row6_col5, #T_abf42_row6_col6, #T_abf42_row6_col7, #T_abf42_row6_col8, #T_abf42_row6_col9, #T_abf42_row7_col2, #T_abf42_row7_col3, #T_abf42_row7_col4, #T_abf42_row7_col5, #T_abf42_row7_col6, #T_abf42_row7_col7, #T_abf42_row7_col8, #T_abf42_row7_col9, #T_abf42_row8_col2, #T_abf42_row8_col3, #T_abf42_row8_col4, #T_abf42_row8_col5, #T_abf42_row8_col6, #T_abf42_row8_col7, #T_abf42_row8_col8, #T_abf42_row8_col9, #T_abf42_row9_col2, #T_abf42_row9_col3, #T_abf42_row9_col4, #T_abf42_row9_col5, #T_abf42_row9_col6, #T_abf42_row9_col7, #T_abf42_row9_col8, #T_abf42_row9_col9 {
#   background-color: #B4EBCA;
#   color: black;
# }
# #T_abf42_row1_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.00);
# }
# #T_abf42_row1_col1, #T_abf42_row6_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 0.44);
# }
# #T_abf42_row2_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.83);
# }
# #T_abf42_row2_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 1.00);
# }
# #T_abf42_row3_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 1.00);
# }
# #T_abf42_row3_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 0.54);
# }
# #T_abf42_row4_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.94);
# }
# #T_abf42_row4_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 0.68);
# }
# #T_abf42_row5_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.87);
# }
# #T_abf42_row5_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 0.45);
# }
# #T_abf42_row6_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.86);
# }
# #T_abf42_row7_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.41);
# }
# #T_abf42_row7_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 0.37);
# }
# #T_abf42_row8_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.43);
# }
# #T_abf42_row8_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 0.00);
# }
# #T_abf42_row9_col0 {
#   background-color: #B4EBCA;
#   background-color: rgba(173, 40, 49, 0.29);
# }
# #T_abf42_row9_col1 {
#   background-color: #B4EBCA;
#   background-color: rgba(188, 244, 245, 0.55);
# }
# </style>
# <table id="T_abf42">
#   <caption>This is an example DataFrame
# </caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abf42_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_abf42_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_abf42_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_abf42_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_abf42_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_abf42_level0_col5" class="col_heading level0 col5" >F</th>
#       <th id="T_abf42_level0_col6" class="col_heading level0 col6" >G</th>
#       <th id="T_abf42_level0_col7" class="col_heading level0 col7" >H</th>
#       <th id="T_abf42_level0_col8" class="col_heading level0 col8" >I</th>
#       <th id="T_abf42_level0_col9" class="col_heading level0 col9" >J</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abf42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abf42_row0_col0" class="data row0 col0" >-0.35</td>
#       <td id="T_abf42_row0_col1" class="data row0 col1" >0.59</td>
#       <td id="T_abf42_row0_col2" class="data row0 col2" >-94.63%</td>
#       <td id="T_abf42_row0_col3" class="data row0 col3" >$0.12</td>
#       <td id="T_abf42_row0_col4" class="data row0 col4" >$(0.21)m</td>
#       <td id="T_abf42_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_abf42_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_abf42_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_abf42_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_abf42_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_abf42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_abf42_row1_col0" class="data row1 col0" >-2.72</td>
#       <td id="T_abf42_row1_col1" class="data row1 col1" >-0.42</td>
#       <td id="T_abf42_row1_col2" class="data row1 col2" >-135.47%</td>
#       <td id="T_abf42_row1_col3" class="data row1 col3" >$-0.43</td>
#       <td id="T_abf42_row1_col4" class="data row1 col4" >$0.14m</td>
#       <td id="T_abf42_row1_col5" class="data row1 col5" >-1</td>
#       <td id="T_abf42_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_abf42_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_abf42_row1_col8" class="data row1 col8" >-1</td>
#       <td id="T_abf42_row1_col9" class="data row1 col9" >-0</td>
#     </tr>
#     <tr>
#       <th id="T_abf42_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_abf42_row2_col0" class="data row2 col0" >0.07</td>
#       <td id="T_abf42_row2_col1" class="data row2 col1" >1.83</td>
#       <td id="T_abf42_row2_col2" class="data row2 col2" >21.65%</td>
#       <td id="T_abf42_row2_col3" class="data row2 col3" >$0.38</td>
#       <td id="T_abf42_row2_col4" class="data row2 col4" >$1.54m</td>
#       <td id="T_abf42_row2_col5" class="data row2 col5" >-1</td>
#       <td id="T_abf42_row2_col6" class="data row2 col6" >-0</td>
#       <td id="T_abf42_row2_col7" class="data row2 col7" >-1</td>
#       <td id="T_abf42_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_abf42_row2_col9" class="data row2 col9" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_abf42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_abf42_row3_col0" class="data row3 col0" >0.64</td>
#       <td id="T_abf42_row3_col1" class="data row3 col1" >-0.04</td>
#       <td id="T_abf42_row3_col2" class="data row3 col2" >94.07%</td>
#       <td id="T_abf42_row3_col3" class="data row3 col3" >$0.93</td>
#       <td id="T_abf42_row3_col4" class="data row3 col4" >$1.51m</td>
#       <td id="T_abf42_row3_col5" class="data row3 col5" >-0</td>
#       <td id="T_abf42_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_abf42_row3_col7" class="data row3 col7" >-0</td>
#       <td id="T_abf42_row3_col8" class="data row3 col8" >-0</td>
#       <td id="T_abf42_row3_col9" class="data row3 col9" >-0</td>
#     </tr>
#     <tr>
#       <th id="T_abf42_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_abf42_row4_col0" class="data row4 col0" >0.45</td>
#       <td id="T_abf42_row4_col1" class="data row4 col1" >0.56</td>
#       <td id="T_abf42_row4_col2" class="data row4 col2" >-1.96%</td>
#       <td id="T_abf42_row4_col3" class="data row4 col3" >$-0.91</td>
#       <td id="T_abf42_row4_col4" class="data row4 col4" >$0.53
